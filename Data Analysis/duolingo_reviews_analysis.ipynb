# %% [markdown]
# # 1. Word Cloud

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# ## a. Preprocessing

# %%
def preprocess_text(text):
    stop_words = set(stopwords.words('english'))

    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token.isalpha()
              and token not in stop_words]
    return tokens

# %%
reviews = pd.read_csv("duolingo_reviews_no_index copy.csv")["Reviews"]
reviews
# Out:
# 0      I would've gave this learning app 5 stars revi...
# 1      Been using this app for more than 30 days, i w...
# 2      Great UI, but very slow paced learning. This i...
# 3      I would've gave this learning app 5 stars revi...
# 4      Been using this app for more than 30 days, i w...
#                              ...
# 858    it's an amazing app that makes me learn so man...
# 859    I love this little cute owl! 🦉🟢 So cute 🥰 and ...
# 860    Came here to give a detailed explanation, I'll...
# 861    I've been using Duolingo for years and have le...
# 862    I started learning Japanese last month, I do a...
# Name: Reviews, Length: 863, dtype: object

# %%
text = " ".join(reviews)
tokens = preprocess_text(text)

# %% [markdown]
# ## b. Visualization

# %%
def generate_wordcloud(words):
    # Generate WordCloud for adjectives
    wordcloud = WordCloud(width=800, height=400,
                          background_color='white').generate(words)

    # Display the WordCloud using matplotlib
    _, ax = plt.subplots(figsize=(10, 5))
    ax.imshow(wordcloud, interpolation='bilinear')
    ax.axis('off')

# %%
processed_text = " ".join(tokens)
generate_wordcloud(processed_text)
