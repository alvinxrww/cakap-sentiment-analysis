# %% [markdown]
# # 1. Word Cloud

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
df = pd.read_csv("../../../Data Collection/Duolingo/duolingo_reviews_no_index.csv")
reviews = df["Reviews"]
reviews
# Out:
# 0       I would've gave this learning app 5 stars revi...
# 1       Been using this app for more than 30 days, i w...
# 2       Great UI, but very slow paced learning. This i...
# 3       I would've gave this learning app 5 stars revi...
# 4       Been using this app for more than 30 days, i w...
#                               ...
# 1018    I bought super Duolingo and used it to learn H...
# 1019    Absolutely amazing. I cannot believe that this...
# 1020    This is best for continuing language practice ...
# 1021    I was charged for one year with the usual "you...
# 1022    Very user friendly, I can't think of a better ...
# Name: Reviews, Length: 1023, dtype: object

# %% [markdown]
# ## a. Preprocessing

# %%
def preprocess_text(text):
    stop_words = set(stopwords.words('english'))

    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token.isalpha()
              and token not in stop_words]
    return tokens

# %%
text = " ".join(reviews)
tokens = preprocess_text(text)

# %% [markdown]
# ## b. Visualization

# %%
def generate_wordcloud(words):
    # Generate WordCloud for adjectives
    wordcloud = WordCloud(width=800, height=400,
                          background_color='white').generate(words)

    # Display the WordCloud using matplotlib
    _, ax = plt.subplots(figsize=(10, 5))
    ax.imshow(wordcloud, interpolation='bilinear')
    ax.axis('off')

# %%
processed_text = " ".join(tokens)
generate_wordcloud(processed_text)
